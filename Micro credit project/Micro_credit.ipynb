# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Data file.csv')
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.shape
# Out:
# (209593, 37)

# %%
print(df.columns,'\n')
print('total variables',len(df.columns))
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')
#
# total variables 37

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# ...

# %% [raw]
# label Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}.
# msisdn mobile number of user.
# aon age on cellular network in days
# daily_decr30 Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah).
# daily_decr90 Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah).
# rental30 Average main account balance over last 30 days.
# rental90 Average main account balance over last 90 days.
# last_rech_date_ma Number of days till last recharge of main account.
# last_rech_date_da Number of days till last recharge of data account.
# last_rech_amt_ma Amount of last recharge of main account (in Indonesian Rupiah).
# cnt_ma_rech30 Number of times main account got recharged in last 30 days.
# fr_ma_rech30 Frequency of main account recharged in last 30 days.
# sumamnt_ma_rech30 Total amount of recharge in main account over last 30 days (in Indonesian Rupiah).
# medianamnt_ma_rech30 Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)
# medianmarechprebal30 Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)
# cnt_ma_rech90 Number of times main account got recharged in last 90 days
# fr_ma_rech90 Frequency of main account recharged in last 90 days
# sumamnt_ma_rech90 Total amount of recharge in main account over last 90 days (in Indonesian Rupee)
# medianamnt_ma_rech90 Median of amount of recharges done in main account over last 90 days at user level (in Indonesian Rupee)
# medianmarechprebal90 Median of main account balance just before recharge in last 90 days at user level (in Indonesian Rupee)
# cnt_da_rech30 Number of times data account got recharged in last 30 days
# fr_da_rech30 Frequency of data account recharged in last 30 days
# cnt_da_rech90 Number of times data account got recharged in last 90 days
# fr_da_rech90 Frequency of data account recharged in last 90 days
# cnt_loans30 Number of loans taken by user in last 30 days
# amnt_loans30 Total amount of loans taken by user in last 30 days
# maxamnt_loans30 maximum amount of loan taken by the user in last 30 days
# medianamnt_loans30 Median of amounts of loan taken by the user in last 30 days
# cnt_loans90 Number of loans taken by user in last 90 days
# amnt_loans90 Total amount of loans taken by user in last 90 days
# maxamnt_loans90 maximum amount of loan taken by the user in last 90 days
# medianamnt_loans90 Median of amounts of loan taken by the user in last 90 days
# payback30 Average payback time in days over last 30 days
# payback90 Average payback time in days over last 90 days
# pcircle telecom circle
# pdate date

# %%
df.tail()
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 209588   1089.19   1089.19                1.0                0.0  ...
# 209589   1728.36   1728.36                4.0                0.0  ...
# 209590   5861.83   8893.20                3.0                0.0  ...
# 209591    411.83    984.58                2.0               38.0  ...
# 209592    483.92    631.20               13.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %% [markdown]
# msisdn is an object datatype so we will have to remove it and it will not effect our model

# %% [markdown]
# Removing unwanted columns

# %%
df=df.drop(['Unnamed: 0','pdate','pcircle','msisdn'],axis = 1)

# %%
df.isnull().sum()
# Out:
# label                   0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# dtype: int64

# %% [markdown]
# As we can see there's no null value and data is quite clean

# %%
corr=df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [raw]
# 1)most of the correlation is near to zero.
# 2)daily_decr30 and daily_decr90 features are highly correlated with each other.
# 3)rental30 and rental90 features are highly correlated with each other.
# 4)cnt_loans30 and amount_loans30 columns are highly correlated with each other.
# 5)amount_loans30 is also highly correlated with amount_loans90 column.
# 6)medianamnt_loans30 and medianamnt_loans90 is highly correlated with each other.

# %% [markdown]
# Checking skewness

# %%
for i in df:
    print(df[i].skew())
# Out:
# -2.270253719912255
# 10.392948821587439
# 3.946230229628723
# 4.252565025615919
# 4.521929009584745
# 4.437680540074498
# 14.790973860995035
# 14.814857231490318
# 3.781148637111509
# 3.283841502993646
# 14.772832636742873
# 6.38678704956917
# 3.512324150491403
# 14.779875343869758
# 3.4252536465582106
# 2.285422796522632
# 4.897949612129103
# 3.752706023594023
# 44.88050323947868
# 17.818364135256427
# 14.776430234353553
# 27.267277681861458
# 28.98808270697841
# 2.713421086900181
# 2.9757194730831107
# 17.658051652037305
# 4.551043016959967
# 16.594407973866023
# 3.150006331942554
# 1.6783037897368753
# 4.895720276504792
# 8.310694656446502
# 6.899950812627082

# %%
#cheking for skewness
for i in df.columns:
    if(df[i].dtype == np.float64):
        plt.figure()
        sns.distplot(df[i])

# %% [markdown]
# from distribution plot we see that maximum variables are highly skewed

# %%
#checking for otliers
collist=df.columns.values
ncol=7
nrow=10
plt.figure(figsize=(nrow,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='red',orient='v')
    plt.tight_layout()

# %% [markdown]
# from box plot we see that lots of variables have a outliers

# %%
#cheking relation between two variables

plt.scatter(df['label'],df['aon'])
plt.ylabel('label')
plt.xlabel('aon')
plt.title('Sctter plt b/w label and aon')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w label and aon')

# %%
plt.scatter(df['aon'],df['aon'])
plt.ylabel('daily_decr30')
plt.xlabel('aon')
plt.title('Sctter plt b/w aon and daily_decr30')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w aon and daily_decr30')

# %%
plt.scatter(df['daily_decr30'],df['daily_decr90'])
plt.ylabel('daily_decr30')
plt.xlabel('daily_decr90')
plt.title('Sctter plt b/w daily_decr30 and daily_decr90')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w daily_decr30 and daily_decr90')

# %%
plt.scatter(df['rental30'],df['rental90'])
plt.ylabel('rental30')
plt.xlabel('rental90')
plt.title('Sctter plt b/w rental30 and rental90')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w rental30 and rental90')

# %%
plt.scatter(df['sumamnt_ma_rech30'],df['sumamnt_ma_rech90'])
plt.ylabel('sumamnt_ma_rech30')
plt.xlabel('sumamnt_ma_rech90')
plt.title('Sctter plt b/w sumamnt_ma_rech30 and sumamnt_ma_rech90')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w sumamnt_ma_rech30 and sumamnt_ma_rech90')

# %%
plt.scatter(df['fr_ma_rech30'],df['fr_ma_rech90'])
plt.ylabel('fr_ma_rech30')
plt.xlabel('fr_ma_rech90')
plt.title('Sctter plt b/w fr_ma_rech30 and fr_ma_rech90')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w fr_ma_rech30 and fr_ma_rech90')

# %%
plt.scatter(df['medianamnt_ma_rech30'],df['medianamnt_ma_rech90'])
plt.ylabel('medianamnt_ma_rech30')
plt.xlabel('medianamnt_ma_rech90')
plt.title('Sctter plt b/w medianamnt_ma_rech30 and medianamnt_ma_rech90')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w medianamnt_ma_rech30 and medianamnt_ma_rech90')

# %%
plt.scatter(df['medianmarechprebal30'],df['medianmarechprebal90'])
plt.ylabel('medianmarechprebal30')
plt.xlabel('medianmarechprebal90')
plt.title('Sctter plt b/w medianmarechprebal30 and medianmarechprebal90')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w medianmarechprebal30 and medianmarechprebal90')

# %%
plt.scatter(df['cnt_da_rech30'],df['cnt_da_rech90'])
plt.ylabel('cnt_da_rech30')
plt.xlabel('cnt_da_rech90')
plt.title('Sctter plt b/w cnt_da_rech30 and cnt_da_rech90')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w cnt_da_rech30 and cnt_da_rech90')

# %%
plt.scatter(df['amnt_loans30'],df['amnt_loans90'])
plt.ylabel('amnt_loans30')
plt.xlabel('amnt_loans90')
plt.title('Sctter plt b/w amnt_loans30 and amnt_loans90')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w amnt_loans30 and amnt_loans90')

# %% [markdown]
# all this variables are highly correlated and they almost have similar data by seeing scatterplot

# %%
#checking unique values
print('unique values in dataset')
for i in df:
    print(i,'-',df[i].nunique())
# Out:
# unique values in dataset
# label - 2
# aon - 4507
# daily_decr30 - 147026
# daily_decr90 - 158670
# rental30 - 132148
# rental90 - 141033
# last_rech_date_ma - 1186
# last_rech_date_da - 1174
# last_rech_amt_ma - 70
# cnt_ma_rech30 - 71
# fr_ma_rech30 - 1083
# sumamnt_ma_rech30 - 15141
# medianamnt_ma_rech30 - 510
# medianmarechprebal30 - 30428
# cnt_ma_rech90 - 110
# fr_ma_rech90 - 89
# sumamnt_ma_rech90 - 31771
# medianamnt_ma_rech90 - 608
# medianmarechprebal90 - 29785
# cnt_da_rech30 - 1066
# fr_da_rech30 - 1072
# cnt_da_rech90 - 27
# fr_da_rech90 - 46
# cnt_loans30 - 40
# amnt_loans30 - 48
# maxamnt_loans30 - 1050
# medianamnt_loans30 - 6
# cnt_loans90 - 1110
# amnt_loans90 - 69
# maxamnt_loans90 - 3
# medianamnt_loans90 - 6
# payback30 - 1363
# payback90 - 2381

# %%
#countplot of label
sns.countplot(x='label',data=df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [raw]
# 1)as we can see that the user paid back the credit amount within 5 days of issuing the loan is more that that not paid.
# 2)it has inbalance dataset

# %%
#multivariate analysis
df.hist(figsize=(20,20))
plt.show()

# %%
#cheking for outliers
dfnew=df.copy()
dfnew.shape
# Out:
# (209593, 33)

# %%
from scipy.stats import zscore
z=np.abs(zscore(dfnew))
threshold=3
np.where(z>3)
df1_new=dfnew[(z<3).all(axis=1)]
df1_new.shape
# Out:
# (161465, 33)

# %%
#after removing outliers we lost near about 20% of data so cant take that much loss of data so we keep the outliers

# %%
y=df.iloc[:,0:1]
print(y)
# Out:
#         label
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 209588      1
# 209589      1
# 209590      1
# 209591      1
# 209592      1
#
# [209593 rows x 1 columns]

# %%
x=df.iloc[:,1:]
print(x)
# Out:
#            aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0        272.0   3055.050000   3065.150000    220.13    260.13
# 1        712.0  12122.000000  12124.750000   3691.26   3691.26
# 2        535.0   1398.000000   1398.000000    900.13    900.13
# 3        241.0     21.228000     21.228000    159.42    159.42
# 4        947.0    150.619333    150.619333   1098.90   1098.90
# ...        ...           ...           ...       ...       ...
# 209588   404.0    151.872333    151.872333   1089.19   1089.19
# 209589  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                     2.0                0.0              1539              2
# ...

# %%
x.isnull().sum()
# Out:
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# dtype: int64

# %%
#Scaling in input variables
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=45)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (157194, 32)
# (157194, 1)
# (52399, 32)
# (52399, 1)

# %%
#Lets chcek logistic regression
from sklearn.linear_model import LogisticRegression
#Importing error metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import GridSearchCV, KFold

# %%
log_class=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
cv=KFold(n_splits=15,random_state=None,shuffle=False)

# %%
clf=GridSearchCV(log_class,grid,cv=cv,n_jobs=-1,scoring='f1_macro')
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[  159  6357]
#  [   85 45798]]
# 0.8770587224947041
#               precision    recall  f1-score   support
#
#            0       0.65      0.02      0.05      6516
#            1       0.88      1.00      0.93     45883
#
#     accuracy                           0.88     52399
#    macro avg       0.76      0.51      0.49     52399
# weighted avg       0.85      0.88      0.82     52399

# %%
clf=GridSearchCV(log_class,grid,cv=cv,n_jobs=-1,scoring='f1_macro')
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[  159  6357]
#  [   85 45798]]
# 0.8770587224947041
#               precision    recall  f1-score   support
#
#            0       0.65      0.02      0.05      6516
#            1       0.88      1.00      0.93     45883
#
#     accuracy                           0.88     52399
#    macro avg       0.76      0.51      0.49     52399
# weighted avg       0.85      0.88      0.82     52399

# %%
#since it is imbalanced dataset so we will focus on auc-roc scor
#Use Under Sampling
from collections import Counter
Counter(y_train['label'])
# Out:
# Counter({1: 137548, 0: 19646})

# %%
#we know that oue target variable is imbalance so we use resampling method to balance it

# %% [markdown]
# under sampling

# %%
from imblearn.under_sampling import NearMiss

# %%
ns = NearMiss(.8)
x_train_ns,y_train_ns = ns.fit_resample(x_train,y_train)
print("The number of classes before fit {}".format(Counter(y_train['label'])))
print("The number of classes after fit {}".format(Counter(y_train_ns['label'])))
# Out:
# The number of classes before fit Counter({1: 137548, 0: 19646})
# The number of classes after fit Counter({1: 24557, 0: 19646})

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_us = RandomForestClassifier()
classifier_us.fit(x_train_ns,y_train_ns)
y_pred=classifier_us.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 4877  1639]
#  [34702 11181]]
# 0.30645623008072675
#               precision    recall  f1-score   support
#
#            0       0.12      0.75      0.21      6516
#            1       0.87      0.24      0.38     45883
#
#     accuracy                           0.31     52399
#    macro avg       0.50      0.50      0.30     52399
# weighted avg       0.78      0.31      0.36     52399

# %% [markdown]
# # over sampling

# %%
from imblearn.over_sampling import RandomOverSampler
os = RandomOverSampler(0.75)
x_train_os,y_train_os = os.fit_resample(x_train,y_train)
print("The number of classes before fit {}".format(Counter(y_train['label'])))
print("The number of classes after fit {}".format(Counter(y_train_os['label'])))
# Out:
# The number of classes before fit Counter({1: 137548, 0: 19646})
# The number of classes after fit Counter({1: 137548, 0: 103161})

# %%
#lets check gaussain nb
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train_os,y_train_os)
y_pred=gnb.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 5789   727]
#  [22468 23415]]
# 0.5573388805129869
#               precision    recall  f1-score   support
#
#            0       0.20      0.89      0.33      6516
#            1       0.97      0.51      0.67     45883
#
#     accuracy                           0.56     52399
#    macro avg       0.59      0.70      0.50     52399
# weighted avg       0.87      0.56      0.63     52399

# %%
#Lets check decision tree
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train_os,y_train_os)
y_pred_dt=dtc.predict(x_test)
print(confusion_matrix(y_test,y_pred_dt))
print(accuracy_score(y_test,y_pred_dt))
print(classification_report(y_test,y_pred_dt))
# Out:
# [[ 3171  3345]
#  [ 3449 42434]]
# 0.8703410370426916
#               precision    recall  f1-score   support
#
#            0       0.48      0.49      0.48      6516
#            1       0.93      0.92      0.93     45883
#
#     accuracy                           0.87     52399
#    macro avg       0.70      0.71      0.70     52399
# weighted avg       0.87      0.87      0.87     52399

# %%
#Lets check extra tree
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier()
etc.fit(x_train_os,y_train_os)
y_pred_et=etc.predict(x_test)
print(confusion_matrix(y_test,y_pred_et))
print(accuracy_score(y_test,y_pred_et))
print(classification_report(y_test,y_pred_et))
# Out:
# [[ 2772  3744]
#  [  985 44898]]
# 0.9097501860722533
#               precision    recall  f1-score   support
#
#            0       0.74      0.43      0.54      6516
#            1       0.92      0.98      0.95     45883
#
#     accuracy                           0.91     52399
#    macro avg       0.83      0.70      0.74     52399
# weighted avg       0.90      0.91      0.90     52399

# %%
#Lets check bagging 
from sklearn.ensemble import BaggingClassifier
bc = BaggingClassifier()
bc.fit(x_train_os,y_train_os)
y_pred_bc=bc.predict(x_test)
print(confusion_matrix(y_test,y_pred_bc))
print(accuracy_score(y_test,y_pred_bc))
print(classification_report(y_test,y_pred_bc))
# Out:
# [[ 3623  2893]
#  [ 2575 43308]]
# 0.8956468634897613
#               precision    recall  f1-score   support
#
#            0       0.58      0.56      0.57      6516
#            1       0.94      0.94      0.94     45883
#
#     accuracy                           0.90     52399
#    macro avg       0.76      0.75      0.76     52399
# weighted avg       0.89      0.90      0.89     52399

# %%
from sklearn.svm import LinearSVC

clf = LinearSVC(random_state=0, tol=1e-5)
clf.fit(x_train, y_train.ravel())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-3d491bb4ff7e> in <module>
#       2
#       3 clf = LinearSVC(random_state=0, tol=1e-5)
# ----> 4 clf.fit(x_train, y_train.ravel())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ravel'

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x_over,y_over= sm.fit_resample(x,y)

# %%
#Let's check random forest
from sklearn.ensemble import RandomForestClassifier
RFclassifier = RandomForestClassifier()
RFclassifier.fit(x_train_os,y_train_os)
y_pred=RFclassifier.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 3288  3228]
#  [ 1408 44475]]
# 0.9115250291036089
#               precision    recall  f1-score   support
#
#            0       0.70      0.50      0.59      6516
#            1       0.93      0.97      0.95     45883
#
#     accuracy                           0.91     52399
#    macro avg       0.82      0.74      0.77     52399
# weighted avg       0.90      0.91      0.91     52399

# %%
#Finding AUC_Score for random forest

from sklearn.metrics import roc_auc_score
auc_score=roc_auc_score(y_test,RFclassifier.predict(x_test))
print("AUC_Score:",auc_score)
# Out:
# AUC_Score: 0.7369586524200055

# %%
#AUC_ROC Curve of random forest

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
y_pred_prob=RFclassifier.predict_proba(x_test)[:,0]
fpr,tpr,thredholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='RFC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest Classifier')
plt.show()

auc_score=roc_auc_score(y_test,RFclassifier.predict(x_test))
print(auc_score)
# Out:
# 0.7369586524200055

# %%
#Saving the model
import joblib

#Save the model as a pickle in a file
joblib.dump(RFclassifier,'Micro_credit.pkl')
# Out:
# ['Micro_credit.pkl']
