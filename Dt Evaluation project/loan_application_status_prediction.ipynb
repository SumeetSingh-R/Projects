# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('loan_status.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
print(df.columns,'\n')
print('total variables',len(df.columns))
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')
#
# total variables 13

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Handling missing values with mode and mean
df['Gender']= df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']= df['Married'].fillna(df['Married'].mode()[0])
df['Dependents']= df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed']= df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['LoanAmount']= df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term']= df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History']= df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['Gender']= label_encoder.fit_transform(df['Gender'])
df['Married']= label_encoder.fit_transform(df['Married'])
df['Dependents']= label_encoder.fit_transform(df['Dependents'])
df['Education']= label_encoder.fit_transform(df['Education'])
df['Self_Employed']= label_encoder.fit_transform(df['Self_Employed'])
df['Property_Area']= label_encoder.fit_transform(df['Property_Area'])
df['Loan_Status']= label_encoder.fit_transform(df['Loan_Status'])
  
df['Gender'].unique()
df['Married'].unique()
df['Dependents'].unique()
df['Education'].unique()
df['Self_Employed'].unique()
df['Property_Area'].unique()
df['Loan_Status'].unique()
# Out:
# array([1, 0])

# %%
df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          0              0
# 1    LP001003       1        1           1          0              0
# 2    LP001005       1        1           0          0              1
# 3    LP001006       1        1           0          1              0
# 4    LP001008       1        0           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          0              0
# 610  LP002979       1        1           3          0              0
# 611  LP002983       1        1           1          0              0
# 612  LP002984       1        1           2          0              0
# 613  LP002990       0        0           0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.describe()
# Out:
#            Gender     Married  Dependents   Education  Self_Employed  \
# count  614.000000  614.000000  614.000000  614.000000     614.000000
# mean     0.817590    0.653094    0.744300    0.218241       0.133550
# std      0.386497    0.476373    1.009623    0.413389       0.340446
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      1.000000    0.000000    0.000000    0.000000       0.000000
# 50%      1.000000    1.000000    0.000000    0.000000       0.000000
# 75%      1.000000    1.000000    1.000000    0.000000       0.000000
# max      1.000000    1.000000    3.000000    1.000000       1.000000
#
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.000000
# std        6109.041673        2926.248369   84.037468         64.372489
# ...

# %%
#multivariate analysis
df.hist(figsize=(20,20))
plt.show()

# %%
sns.countplot(df['Gender'])
plt.show()

# %%
sns.countplot(df['Married'])
plt.show()

# %%
sns.countplot(df['Dependents'])
plt.show()

# %%
sns.countplot(df['Education'])
plt.show()

# %%
sns.countplot(df['Self_Employed'])
plt.show()

# %%
sns.countplot(df['ApplicantIncome'])
plt.show()

# %%
sns.countplot(df['CoapplicantIncome'])
plt.show()

# %%
sns.countplot(df['LoanAmount'])
plt.show()

# %%
sns.countplot(df['Loan_Amount_Term'])
plt.show()

# %%
sns.countplot(df['Credit_History'])
plt.show()

# %%
sns.countplot(df['Property_Area'])
plt.show()

# %%
sns.countplot(df['Loan_Status'])
plt.show()

# %%
sns.violinplot(data=df, x="Gender")
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
sns.violinplot(data=df, x="Married")
# Out:
# <AxesSubplot:xlabel='Married'>

# %%
sns.violinplot(data=df, x="Dependents")
# Out:
# <AxesSubplot:xlabel='Dependents'>

# %%
sns.violinplot(data=df, x="Education")
# Out:
# <AxesSubplot:xlabel='Education'>

# %%
sns.violinplot(data=df, x="Self_Employed")
# Out:
# <AxesSubplot:xlabel='Self_Employed'>

# %%
sns.violinplot(data=df, x="ApplicantIncome")
# Out:
# <AxesSubplot:xlabel='ApplicantIncome'>

# %%
sns.violinplot(data=df, x="CoapplicantIncome")
# Out:
# <AxesSubplot:xlabel='CoapplicantIncome'>

# %%
sns.violinplot(data=df, x="LoanAmount")
# Out:
# <AxesSubplot:xlabel='LoanAmount'>

# %%
sns.violinplot(data=df, x="Loan_Amount_Term")
# Out:
# <AxesSubplot:xlabel='Loan_Amount_Term'>

# %%
sns.violinplot(data=df, x="Credit_History")
# Out:
# <AxesSubplot:xlabel='Credit_History'>

# %%
sns.violinplot(data=df, x="Property_Area")
# Out:
# <AxesSubplot:xlabel='Property_Area'>

# %%
sns.violinplot(data=df, x="Loan_Status")
# Out:
# <AxesSubplot:xlabel='Loan_Status'>

# %%
sns.lineplot(data=df, x="Married", y="Loan_Status")
plt.show()
sns.scatterplot(data=df, x="Married", y="Loan_Status")
sns.jointplot(data=df, x="Married", y="Loan_Status")

# %%
sns.lineplot(data=df, x="Dependents", y="Loan_Status")
plt.show()
sns.scatterplot(data=df, x="Dependents", y="Loan_Status")
sns.jointplot(data=df, x="Dependents", y="Loan_Status")

# %%
sns.lineplot(data=df, x="Education", y="Loan_Status")
plt.show()
sns.scatterplot(data=df, x="Education", y="Loan_Status")
sns.jointplot(data=df, x="Education", y="Loan_Status")

# %%
sns.lineplot(data=df, x="Self_Employed", y="Loan_Status")
plt.show()
sns.scatterplot(data=df, x="Self_Employed", y="Loan_Status")
sns.jointplot(data=df, x="Self_Employed", y="Loan_Status")

# %%
sns.lineplot(data=df, x="ApplicantIncome", y="Loan_Status")
plt.show()
sns.scatterplot(data=df, x="ApplicantIncome", y="Loan_Status")
sns.jointplot(data=df, x="ApplicantIncome", y="Loan_Status")

# %%
sns.lineplot(data=df, x="CoapplicantIncome", y="Loan_Status")
plt.show()
sns.scatterplot(data=df, x="CoapplicantIncome", y="Loan_Status")
sns.jointplot(data=df, x="CoapplicantIncome", y="Loan_Status")

# %%
sns.lineplot(data=df, x="Loan_Amount_Term", y="Loan_Status")
plt.show()
sns.scatterplot(data=df, x="Loan_Amount_Term", y="Loan_Status")
sns.jointplot(data=df, x="Loan_Amount_Term", y="Loan_Status")

# %%
sns.lineplot(data=df, x="Credit_History", y="Loan_Status")
plt.show()
sns.scatterplot(data=df, x="Credit_History", y="Loan_Status")
sns.jointplot(data=df, x="Credit_History", y="Loan_Status")

# %%
sns.lineplot(data=df, x="Property_Area", y="Loan_Status")
plt.show()
sns.scatterplot(data=df, x="Property_Area", y="Loan_Status")
sns.jointplot(data=df, x="Property_Area", y="Loan_Status")

# %%
from numpy import median
sns.barplot(x='Loan_Status', y='ApplicantIncome', hue= 'Gender',data=df, estimator=median)
plt.show()

# %%
from numpy import median
sns.barplot(x='Loan_Status', y='ApplicantIncome', hue= 'Dependents',data=df, estimator=median)
plt.show()

# %%
from numpy import median
sns.barplot(x='Loan_Status', y='ApplicantIncome', hue= 'Married',data=df, estimator=median)
plt.show()

# %%
f,ax = plt.subplots(figsize=(15,10))
sns.boxplot(x='Dependents', y='ApplicantIncome', data=df, hue='Married',palette='Set3')
plt.legend(loc='best')
plt.show()

# %%
sns.violinplot(x="Loan_Status", y="Education", hue="Gender", data=df, palette="muted", split=True,inner="stick")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),cmap='rocket',annot=True)
# Out:
# <AxesSubplot:>

# %%
#Removing unwanted columns
df=df.drop(['Loan_ID'], axis = 1)
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
for i in df:
    print(df[i].skew())
# Out:
# -1.6487952886687591
# -0.6448502342244192
# 1.015550985536672
# 1.367622010164177
# 2.159796196971883
# 6.539513113994625
# 7.491531216657306
# 2.726601144105299
# -2.3896799467122745
# -1.963600485467902
# -0.06619614490788747
# -0.8099980938586473

# %%
#cheking for skewness
for i in df.columns:
    if(df[i].dtype == np.float64):
        plt.figure()
        sns.distplot(df[i])

# %%
#Lets treat the skewness
import numpy as np
df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df.skew().loc[col]>0.5:
            df[col]=np.sqrt(df[col])
        if df.skew().loc[col]<-0.5:
            df[col]=np.cbrt(df[col])

# %%
#Again check skewness
df.skew()
# Out:
# Gender              -1.648795
# Married             -0.644850
# Dependents           0.567810
# Education            1.367622
# Self_Employed        2.159796
# ApplicantIncome      2.967286
# CoapplicantIncome    0.979561
# LoanAmount           1.314162
# Loan_Amount_Term    -3.573315
# Credit_History      -2.014285
# Property_Area       -0.066196
# Loan_Status         -0.809998
# dtype: float64

# %%
#cheking for skewness
for i in df.columns:
    if(df[i].dtype == np.float64):
        plt.figure()
        sns.distplot(df[i])

# %%
#checking for otliers
collist=df.columns.values
ncol=7
nrow=10
plt.figure(figsize=(nrow,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='red',orient='v')
    plt.tight_layout()

# %%
#remove outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
df_new=df[(z<3).all(axis=1)]
print(df.shape,df_new.shape)
# Out:
# (614, 12) (580, 12)

# %%
x=df_new.drop(['Loan_Status'],axis=1)
x.shape
# Out:
# (580, 11)

# %%
y=df_new.iloc[:,11:]
print(y)
# Out:
#      Loan_Status
# 0            1.0
# 1            0.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 609          1.0
# 610          1.0
# 611          1.0
# 612          1.0
# 613          0.0
#
# [580 rows x 1 columns]

# %%
#Scaling in input variables
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=45)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (435, 11)
# (435, 1)
# (145, 11)
# (145, 1)

# %%
#Lets chcek logistic regression
from sklearn.linear_model import LogisticRegression
#Importing error metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import GridSearchCV, KFold

# %%
log_class=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['none','l2']}
cv=KFold(n_splits=15,random_state=None,shuffle=False)

# %%
clf=GridSearchCV(log_class,grid,cv=cv,n_jobs=-1,scoring='f1_macro')
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[24 25]
#  [ 1 95]]
# 0.8206896551724138
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.49      0.65        49
#          1.0       0.79      0.99      0.88        96
#
#     accuracy                           0.82       145
#    macro avg       0.88      0.74      0.76       145
# weighted avg       0.85      0.82      0.80       145

# %%
#since it is imbalanced dataset so we will focus on auc-roc scor
#Use Under Sampling
from collections import Counter
Counter(y_train['Loan_Status'])
# Out:
# Counter({1.0: 304, 0.0: 131})

# %% [markdown]
# under sampling

# %%
from imblearn.under_sampling import NearMiss
ns = NearMiss(.8)
x_train_ns,y_train_ns = ns.fit_resample(x_train,y_train)
print("The number of classes before fit {}".format(Counter(y_train['Loan_Status'])))
print("The number of classes after fit {}".format(Counter(y_train_ns['Loan_Status'])))
# Out:
# The number of classes before fit Counter({1.0: 304, 0.0: 131})
# The number of classes after fit Counter({1.0: 163, 0.0: 131})

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_us = RandomForestClassifier()
classifier_us.fit(x_train_ns,y_train_ns)
y_pred=classifier_us.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[36 13]
#  [34 62]]
# 0.6758620689655173
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.73      0.61        49
#          1.0       0.83      0.65      0.73        96
#
#     accuracy                           0.68       145
#    macro avg       0.67      0.69      0.67       145
# weighted avg       0.72      0.68      0.68       145

# %% [markdown]
# over sampling

# %%
from imblearn.over_sampling import RandomOverSampler
os = RandomOverSampler(0.75)
x_train_os,y_train_os = os.fit_resample(x_train,y_train)
print("The number of classes before fit {}".format(Counter(y_train['Loan_Status'])))
print("The number of classes after fit {}".format(Counter(y_train_os['Loan_Status'])))
# Out:
# The number of classes before fit Counter({1.0: 304, 0.0: 131})
# The number of classes after fit Counter({1.0: 304, 0.0: 228})

# %%
#lets check gaussain nb
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train_os,y_train_os)
y_pred=gnb.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[24 25]
#  [ 1 95]]
# 0.8206896551724138
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.49      0.65        49
#          1.0       0.79      0.99      0.88        96
#
#     accuracy                           0.82       145
#    macro avg       0.88      0.74      0.76       145
# weighted avg       0.85      0.82      0.80       145

# %%
#Lets check decision tree
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train_os,y_train_os)
y_pred_dt=dtc.predict(x_test)
print(confusion_matrix(y_test,y_pred_dt))
print(accuracy_score(y_test,y_pred_dt))
print(classification_report(y_test,y_pred_dt))
# Out:
# [[32 17]
#  [25 71]]
# 0.7103448275862069
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.65      0.60        49
#          1.0       0.81      0.74      0.77        96
#
#     accuracy                           0.71       145
#    macro avg       0.68      0.70      0.69       145
# weighted avg       0.72      0.71      0.71       145

# %%
#Lets check extra tree
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier()
etc.fit(x_train_os,y_train_os)
y_pred_et=etc.predict(x_test)
print(confusion_matrix(y_test,y_pred_et))
print(accuracy_score(y_test,y_pred_et))
print(classification_report(y_test,y_pred_et))
# Out:
# [[25 24]
#  [ 7 89]]
# 0.7862068965517242
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.51      0.62        49
#          1.0       0.79      0.93      0.85        96
#
#     accuracy                           0.79       145
#    macro avg       0.78      0.72      0.73       145
# weighted avg       0.79      0.79      0.77       145

# %%
#Lets check bagging 
from sklearn.ensemble import BaggingClassifier
bc = BaggingClassifier()
bc.fit(x_train_os,y_train_os)
y_pred_bc=bc.predict(x_test)
print(confusion_matrix(y_test,y_pred_bc))
print(accuracy_score(y_test,y_pred_bc))
print(classification_report(y_test,y_pred_bc))
# Out:
# [[30 19]
#  [14 82]]
# 0.7724137931034483
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.61      0.65        49
#          1.0       0.81      0.85      0.83        96
#
#     accuracy                           0.77       145
#    macro avg       0.75      0.73      0.74       145
# weighted avg       0.77      0.77      0.77       145

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x_over,y_over= sm.fit_resample(x,y)

# %%
#Let's check random forest
from sklearn.ensemble import RandomForestClassifier
RFclassifier = RandomForestClassifier()
RFclassifier.fit(x_train_os,y_train_os)
y_pred=RFclassifier.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[25 24]
#  [11 85]]
# 0.7586206896551724
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.51      0.59        49
#          1.0       0.78      0.89      0.83        96
#
#     accuracy                           0.76       145
#    macro avg       0.74      0.70      0.71       145
# weighted avg       0.75      0.76      0.75       145

# %%
#Finding AUC_Score for random forest

from sklearn.metrics import roc_auc_score
auc_score=roc_auc_score(y_test,RFclassifier.predict(x_test))
print("AUC_Score:",auc_score)
# Out:
# AUC_Score: 0.6978103741496599

# %%
#AUC_ROC Curve of random forest

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
y_pred_prob=RFclassifier.predict_proba(x_test)[:,0]
fpr,tpr,thredholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='RFC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest Classifier')
plt.show()

auc_score=roc_auc_score(y_test,RFclassifier.predict(x_test))
print(auc_score)
# Out:
# 0.6978103741496599

# %%
#Saving the model
import joblib

#Save the model as a pickle in a file
joblib.dump(RFclassifier,'loan_application.pkl')
# Out:
# ['loan_application.pkl']
