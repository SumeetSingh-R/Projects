# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('hr.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
print(df.columns,'\n')
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#multivariate analysis
df.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# * Employees are between the age of 25-45
#
# * Maximum employees have spent between the year 0-5 with current manager
#
# * Major employees are spending between 2-3 years in current role
#
# * Employess tends to spend 10 years in one company
#
# * Most of the employees stay near to they work place

# %%
sns.countplot(df['Attrition'])
plt.show()

# %% [markdown]
# * Data is not standarize and also and lot of employees tend to leave rather than stay.

# %%
sns.countplot(df['BusinessTravel'])
plt.show()

# %% [markdown]
# * Majority of the employees tend to Travel Rarely

# %%
sns.countplot(df['Department'])
plt.show()

# %% [markdown]
# * Research & Development department have most employees shows companies hire more people for in need for this department

# %%
sns.countplot(df['EducationField'])
plt.show()

# %% [markdown]
# * Employees having Life Science degree are mostly employeed followed by Medical students

# %%
sns.violinplot(data=df, x="Age")
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# * Maximum Employees are between the age of 30-40

# %%
sns.violinplot(data=df, x="DailyRate")
# Out:
# <AxesSubplot:xlabel='DailyRate'>

# %% [markdown]
# * Daily rate is highly divided from 250-1500

# %%
sns.violinplot(data=df, x="DistanceFromHome")
# Out:
# <AxesSubplot:xlabel='DistanceFromHome'>

# %% [markdown]
# * Employees tend to live within 10 at maximum of time

# %%
sns.violinplot(data=df, x="Education")
# Out:
# <AxesSubplot:xlabel='Education'>

# %% [markdown]
# * Majority of the employees have 3 and 4 education

# %%
sns.violinplot(data=df, x="TotalWorkingYears")
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears'>

# %% [markdown]
# * Total working experience of the employees are around 10 years

# %%
sns.violinplot(data=df, x="TrainingTimesLastYear")
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear'>

# %% [markdown]
# * most of the employees have done training 2-3 times in last year

# %%
sns.violinplot(data=df, x="WorkLifeBalance")
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance'>

# %% [markdown]
# * Majority of the employees are having a work life balance of 3

# %%
sns.violinplot(data=df, x="YearsAtCompany")
# Out:
# <AxesSubplot:xlabel='YearsAtCompany'>

# %% [markdown]
# * Employees are spending 0-10 years majority

# %%
sns.violinplot(data=df, x="YearsInCurrentRole")
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole'>

# %% [markdown]
# * After 5 years employees tend to change the role

# %%
sns.violinplot(data=df, x="YearsWithCurrManager")
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager'>

# %% [markdown]
# * Majority of the employees are with current managers for arond 2.5 years

# %%
sns.lineplot(data=df, x="Age", y="Attrition")
sns.scatterplot(data=df, x="Age", y="Attrition")
sns.jointplot(data=df, x="Age", y="Attrition")

# %% [markdown]
# * Employees with the age of 20-26 tends to leave the organisation very less

# %%
sns.lineplot(data=df, x="DailyRate", y="Attrition")
sns.scatterplot(data=df, x="DailyRate", y="Attrition")
sns.jointplot(data=df, x="DailyRate", y="Attrition")

# %% [markdown]
# * It seems that Wages don't really depends on attrition of the employee

# %%
sns.lineplot(data=df, x="Department", y="Attrition")
sns.scatterplot(data=df, x="Department", y="Attrition")
sns.jointplot(data=df, x="Department", y="Attrition")

# %% [markdown]
# * Research and development department employes leave less than rest

# %%
sns.lineplot(data=df, x="EducationField", y="Attrition")
sns.scatterplot(data=df, x="EducationField", y="Attrition")
sns.jointplot(data=df, x="EducationField", y="Attrition")

# %% [markdown]
# * Attrition In Human Resource department is the most

# %%
sns.lineplot(data=df, x="TotalWorkingYears", y="Attrition")
sns.scatterplot(data=df, x="TotalWorkingYears", y="Attrition")
sns.jointplot(data=df, x="TotalWorkingYears", y="Attrition")

# %% [markdown]
# * Attrition b/w the experience range of 0-7 years is high

# %%
sns.lineplot(data=df, x="TrainingTimesLastYear", y="Attrition")
sns.scatterplot(data=df, x="TrainingTimesLastYear", y="Attrition")
sns.jointplot(data=df, x="TrainingTimesLastYear", y="Attrition")

# %% [markdown]
# * Training doesn't realy effect the attrition rate

# %%
sns.lineplot(data=df, x="WorkLifeBalance", y="Attrition")
sns.scatterplot(data=df, x="WorkLifeBalance", y="Attrition")
sns.jointplot(data=df, x="WorkLifeBalance", y="Attrition")

# %% [markdown]
# * Employees having the work life balance between 1-2 is having hight attrition rate

# %%
sns.lineplot(data=df, x="DistanceFromHome", y="Attrition")
sns.scatterplot(data=df, x="DistanceFromHome", y="Attrition")
sns.jointplot(data=df, x="DistanceFromHome", y="Attrition")

# %% [markdown]
# * People who live far from the office having more attrition rate

# %%
sns.lineplot(data=df, x="YearsAtCompany", y="Attrition")
sns.scatterplot(data=df, x="YearsAtCompany", y="Attrition")
sns.jointplot(data=df, x="YearsAtCompany", y="Attrition")

# %% [markdown]
# * people who is in the company for 23-25 years have major attrition rate

# %%
sns.lineplot(data=df, x="YearsInCurrentRole", y="Attrition")
sns.scatterplot(data=df, x="YearsInCurrentRole", y="Attrition")
sns.jointplot(data=df, x="YearsInCurrentRole", y="Attrition")

# %% [markdown]
# * People at early years of their experience have high attrittion rate

# %%
sns.lineplot(data=df, x="YearsWithCurrManager", y="Attrition")
sns.scatterplot(data=df, x="YearsWithCurrManager", y="Attrition")
sns.jointplot(data=df, x="YearsWithCurrManager", y="Attrition")

# %% [markdown]
# * People with the current amangers for 12.5 to 15 years are having high attrition

# %%
sns.lineplot(data=df, x="YearsSinceLastPromotion", y="Attrition")
sns.scatterplot(data=df, x="YearsSinceLastPromotion", y="Attrition")
sns.jointplot(data=df, x="YearsSinceLastPromotion", y="Attrition")

# %% [markdown]
# * Promotion highly depends on attrition

# %%
from numpy import median
sns.barplot(x='Attrition', y='MonthlyIncome', hue= 'Gender',data=df, estimator=median)
plt.show()

# %%
from numpy import median
sns.barplot(x='Attrition', y='MonthlyIncome', hue= 'JobSatisfaction',data=df, estimator=median)
plt.show()

# %%
from numpy import median
sns.barplot(x='Attrition', y='MonthlyIncome', hue= 'MaritalStatus',data=df, estimator=median)
plt.show()

# %% [markdown]
# * We can conclude that people with less monthlyincome (around 3000 units) are likely to leave the organization than those with better income (around 5000 units)

# %%
f,ax = plt.subplots(figsize=(15,10))
sns.boxplot(x='JobSatisfaction', y='MonthlyIncome', data=df, hue='JobLevel',palette='Set3')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# * We can clearly observe the difference in monthly income across different job levels. The difference in the monthly income is observed by the median value for different job satisfaction level.

# %%
sns.violinplot(x="Attrition", y="YearsAtCompany", hue="Gender", data=df, palette="muted", split=True,inner="stick")
plt.show()

# %% [markdown]
# * Here, we have plotted the number of years spent in an organization based on gender. The middle dashed line shows the median. The lines above and below the median show the interquartile range. The denser part shows the maximum population falls under that range and thinner part shows the lesser population

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),cmap='rocket',annot=True)
# Out:
# <AxesSubplot:>

# %%
df['age_group'] = pd.cut(df['Age'], 3, labels=['Young', 'Middle', 'Senior']) #Slicing the continuous data into various groups 
                                                                             #Age Group is the name of new column
sns.factorplot(x =   'Attrition',     # Categorical
               y =   'MonthlyIncome',      # Continuous
               hue = 'JobLevel',    # Categorical
               col = 'age_group',
               col_wrap=2,           # Wrap facet after two axes
               kind = 'box',
               data = df)
plt.show()

# %% [markdown]
# * Above factor plot shows that monthly income plays an important role in retaining the employees in an organization. It can be observed across job levels and different age groups.

# %%
g = sns.FacetGrid(df, col="JobSatisfaction", row="Gender")
g.map(sns.kdeplot, "MonthlyIncome", "YearsInCurrentRole")
plt.show()

# %% [markdown]
# * We have created kernel density estimation plot. It displays the density distribution of two continuous variables (namely, Monthly income and years in current role). We have created facets according to different job satisfaction levels and gender.

# %%
data1 = ['Attrition','Age','MonthlyIncome','DistanceFromHome']
sns.pairplot(df[data1], kind="reg", diag_kind = "kde" , hue = 'Attrition' )
plt.show()

# %% [markdown]
# * Pairwise plots between continuous variables show the relationship between them. For example. observing the relationship between Age and Monthly Income, we can find that with age, monthly income has increased but the increase is not similar for both groups (Attrition and Retention).

# %%
data2 = ['Gender', 'HourlyRate','DailyRate','MonthlyRate','PercentSalaryHike']
sns.pairplot(df[data2], kind="reg", diag_kind = "kde" , hue = 'Gender' )
plt.show()

# %% [markdown]
# * The above plot does not convey much of any relationship between variables across gender. This shows that hourly rate, daily rate, monthly rate and percent salary hike is same for both female and male employees.

# %%
#Removing unwanted columns
df=df.drop(['EmployeeNumber'], axis = 1)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.iloc[:,10:26]
# Out:
#       Gender  HourlyRate  JobInvolvement  JobLevel                    JobRole  \
# 0     Female          94               3         2            Sales Executive
# 1       Male          61               2         2         Research Scientist
# 2       Male          92               2         1      Laboratory Technician
# 3     Female          56               3         1         Research Scientist
# 4       Male          40               3         1      Laboratory Technician
# ...      ...         ...             ...       ...                        ...
# 1465    Male          41               4         2      Laboratory Technician
# 1466    Male          42               2         3  Healthcare Representative
# 1467    Male          87               4         2     Manufacturing Director
# 1468    Male          63               2         2            Sales Executive
# 1469    Male          82               4         2      Laboratory Technician
#
# ...

# %%
# Now encoding required columns for our machine learning.

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['Attrition']= label_encoder.fit_transform(df['Attrition'])
  
df['Attrition'].unique()
# Out:
# array([1, 0])

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['BusinessTravel']= label_encoder.fit_transform(df['BusinessTravel'])
  
df['BusinessTravel'].unique()
# Out:
# array([2, 1, 0])

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['Department']= label_encoder.fit_transform(df['Department'])
  
df['Department'].unique()
# Out:
# array([2, 1, 0])

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['EducationField']= label_encoder.fit_transform(df['EducationField'])
  
df['EducationField'].unique()
# Out:
# array([1, 4, 3, 2, 5, 0])

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['Gender']= label_encoder.fit_transform(df['Gender'])
  
df['Gender'].unique()
# Out:
# array([0, 1])

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['JobRole']= label_encoder.fit_transform(df['JobRole'])
  
df['JobRole'].unique()
# Out:
# array([7, 6, 2, 4, 0, 3, 8, 5, 1])

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['MaritalStatus']= label_encoder.fit_transform(df['MaritalStatus'])
  
df['MaritalStatus'].unique()
# Out:
# array([2, 1, 0])

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['Over18']= label_encoder.fit_transform(df['Over18'])
  
df['Over18'].unique()
# Out:
# array([0])

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['OverTime']= label_encoder.fit_transform(df['OverTime'])
  
df['OverTime'].unique()
# Out:
# array([1, 0])

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['age_group']= label_encoder.fit_transform(df['age_group'])
  
df['age_group'].unique()
# Out:
# array([0, 1, 2])

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeCount               0.000000
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# ...

# %%
#Ploting skewness
for i in df.columns:
    if(df[i].all()):
        plt.figure()
        sns.distplot(df[i])

# %% [markdown]
# * We have some skewed data

# %%
#Lets treat the skewness
import numpy as np
df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df.skew().loc[col]>0.5:
            df[col]=np.sqrt(df[col])
        if df.skew().loc[col]<-0.5:
            df[col]=np.cbrt(df[col])

# %%
#Again check skewness
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -2.319100
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.398114
# Education                  -0.289681
# EducationField             -0.162769
# EmployeeCount               0.000000
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.593923
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               0.861960
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.031303
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.655412
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# ...

# %% [markdown]
# * We have treated skewness using square root

# %%
x=df.drop(['Attrition'],axis=1)
x.shape
# Out:
# (1470, 34)

# %%
y=df.iloc[:,1:2]
print(y)
# Out:
#       Attrition
# 0           1.0
# 1           0.0
# 2           1.0
# 3           0.0
# 4           0.0
# ...         ...
# 1465        0.0
# 1466        0.0
# 1467        0.0
# 1468        0.0
# 1469        0.0
#
# [1470 rows x 1 columns]

# %%
#Scaling in input variables
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=45)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1102, 34)
# (1102, 1)
# (368, 34)
# (368, 1)

# %%
#Lets chcek logistic regression
from sklearn.linear_model import LogisticRegression
#Importing error metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import GridSearchCV, KFold

# %%
log_class=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
cv=KFold(n_splits=15,random_state=None,shuffle=False)

# %%
clf=GridSearchCV(log_class,grid,cv=cv,n_jobs=-1,scoring='f1_macro')
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[288  10]
#  [ 41  29]]
# 0.8614130434782609
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.97      0.92       298
#          1.0       0.74      0.41      0.53        70
#
#     accuracy                           0.86       368
#    macro avg       0.81      0.69      0.73       368
# weighted avg       0.85      0.86      0.85       368

# %%
clf=GridSearchCV(log_class,grid,cv=cv,n_jobs=-1,scoring='f1_macro')
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[288  10]
#  [ 41  29]]
# 0.8614130434782609
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.97      0.92       298
#          1.0       0.74      0.41      0.53        70
#
#     accuracy                           0.86       368
#    macro avg       0.81      0.69      0.73       368
# weighted avg       0.85      0.86      0.85       368

# %%
#since it is imbalanced dataset so we will focus on auc-roc scor
#Use Under Sampling
from collections import Counter
Counter(y_train['Attrition'])
# Out:
# Counter({0.0: 935, 1.0: 167})

# %% [markdown]
# * we know that oue target variable is imbalance so we use resampling method to balance it

# %% [markdown]
# # under sampling

# %%
from imblearn.under_sampling import NearMiss

# %%
ns = NearMiss(.8)
x_train_ns,y_train_ns = ns.fit_resample(x_train,y_train)
print("The number of classes before fit {}".format(Counter(y_train['Attrition'])))
print("The number of classes after fit {}".format(Counter(y_train_ns['Attrition'])))
# Out:
# The number of classes before fit Counter({0.0: 935, 1.0: 167})
# The number of classes after fit Counter({0.0: 208, 1.0: 167})

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_us = RandomForestClassifier()
classifier_us.fit(x_train_ns,y_train_ns)
y_pred=classifier_us.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[175 123]
#  [ 20  50]]
# 0.6114130434782609
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.59      0.71       298
#          1.0       0.29      0.71      0.41        70
#
#     accuracy                           0.61       368
#    macro avg       0.59      0.65      0.56       368
# weighted avg       0.78      0.61      0.65       368

# %% [markdown]
# # over sampling

# %%
from imblearn.over_sampling import RandomOverSampler
os = RandomOverSampler(0.75)
x_train_os,y_train_os = os.fit_resample(x_train,y_train)
print("The number of classes before fit {}".format(Counter(y_train['Attrition'])))
print("The number of classes after fit {}".format(Counter(y_train_os['Attrition'])))
# Out:
# The number of classes before fit Counter({0.0: 935, 1.0: 167})
# The number of classes after fit Counter({0.0: 935, 1.0: 701})

# %%
#lets check gaussain nb
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train_os,y_train_os)
y_pred=gnb.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[187 111]
#  [ 15  55]]
# 0.657608695652174
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.63      0.75       298
#          1.0       0.33      0.79      0.47        70
#
#     accuracy                           0.66       368
#    macro avg       0.63      0.71      0.61       368
# weighted avg       0.81      0.66      0.69       368

# %%
#Lets check decision tree
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train_os,y_train_os)
y_pred_dt=dtc.predict(x_test)
print(confusion_matrix(y_test,y_pred_dt))
print(accuracy_score(y_test,y_pred_dt))
print(classification_report(y_test,y_pred_dt))
# Out:
# [[248  50]
#  [ 51  19]]
# 0.7255434782608695
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.83      0.83       298
#          1.0       0.28      0.27      0.27        70
#
#     accuracy                           0.73       368
#    macro avg       0.55      0.55      0.55       368
# weighted avg       0.72      0.73      0.72       368

# %%
#Lets check extra tree
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier()
etc.fit(x_train_os,y_train_os)
y_pred_et=etc.predict(x_test)
print(confusion_matrix(y_test,y_pred_et))
print(accuracy_score(y_test,y_pred_et))
print(classification_report(y_test,y_pred_et))
# Out:
# [[294   4]
#  [ 61   9]]
# 0.8233695652173914
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.99      0.90       298
#          1.0       0.69      0.13      0.22        70
#
#     accuracy                           0.82       368
#    macro avg       0.76      0.56      0.56       368
# weighted avg       0.80      0.82      0.77       368

# %%
#Lets check bagging 
from sklearn.ensemble import BaggingClassifier
bc = BaggingClassifier()
bc.fit(x_train_os,y_train_os)
y_pred_bc=bc.predict(x_test)
print(confusion_matrix(y_test,y_pred_bc))
print(accuracy_score(y_test,y_pred_bc))
print(classification_report(y_test,y_pred_bc))
# Out:
# [[284  14]
#  [ 53  17]]
# 0.8179347826086957
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.95      0.89       298
#          1.0       0.55      0.24      0.34        70
#
#     accuracy                           0.82       368
#    macro avg       0.70      0.60      0.62       368
# weighted avg       0.79      0.82      0.79       368

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x_over,y_over= sm.fit_resample(x,y)

# %%
#Let's check random forest
from sklearn.ensemble import RandomForestClassifier
RFclassifier = RandomForestClassifier()
RFclassifier.fit(x_train_os,y_train_os)
y_pred=RFclassifier.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[292   6]
#  [ 54  16]]
# 0.8369565217391305
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.98      0.91       298
#          1.0       0.73      0.23      0.35        70
#
#     accuracy                           0.84       368
#    macro avg       0.79      0.60      0.63       368
# weighted avg       0.82      0.84      0.80       368

# %%
#Finding AUC_Score for Decesion tree

from sklearn.metrics import roc_auc_score
auc_score=roc_auc_score(y_test,dtc.predict(x_test))
print("AUC_Score:",auc_score)
# Out:
# AUC_Score: 0.5518216682646213

# %%
#AUC_ROC Curve of random forest

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
y_pred_prob=dtc.predict_proba(x_test)[:,0]
fpr,tpr,thredholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='RFC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Decision Tree Classifier')
plt.show()

auc_score=roc_auc_score(y_test,dtc.predict(x_test))
print(auc_score)
# Out:
# 0.5518216682646213

# %%
#Saving the model
import joblib

#Save the model as a pickle in a file
joblib.dump(RFclassifier,'hr_analytics.pkl')
# Out:
# ['hr_analytics.pkl']
