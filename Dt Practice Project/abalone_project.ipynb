# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('abalone.csv')
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
print(df.columns,'\n')
print('total variables',len(df.columns))
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')
#
# total variables 9

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
#plotting the countplot

sns.countplot(df['Rings'])
plt.show()

# %% [markdown]
# Majority of the abalone are having the ring between 6-13

# %%
#plotting the countplot
for i in df.columns:
    sns.countplot(x=df[i],data=df)
    plt.tight_layout
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e81d1892f756> in <module>
#       3     sns.countplot(x=df[i],data=df)
#       4     plt.tight_layout
# ----> 5     plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %% [markdown]
# As we can see we have majority of males abalone

# %%
#multivariate analysis
df.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# Length b/w 0.5-0.6 are maximum
#
# Diameter b/w 0.4-0.5 are maximum
#
# Height b/w 0.1-0.2 are maximum
#
# Whole Weight b/w 0-1.5 are maximum
#
# shucked weight b/w 0-0.6 are maximum
#
# Viscera weight b/w 0-0.3 are maximum
#
# Shell Weight b/w 0-0.4 are maximum
#
# Rings b/w 6-13 are maximum

# %%
#cheking relation between two variables

plt.scatter(df['Length'],df['Rings'])
plt.ylabel('Rings')
plt.xlabel('Length')
plt.title('Sctter plt b/w Length and Rings')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w Length and Rings')

# %% [markdown]
# As the length increase the rings are also increasing

# %%
#cheking relation between two variables

plt.scatter(df['Diameter'],df['Rings'])
plt.ylabel('Rings')
plt.xlabel('Diameter')
plt.title('Sctter plt b/w Diameter and Rings')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w Diameter and Rings')

# %% [markdown]
# As the Diameter increase the rings are also increasing

# %%
#cheking relation between two variables

plt.scatter(df['Height'],df['Rings'])
plt.ylabel('Rings')
plt.xlabel('Height')
plt.title('Sctter plt b/w Height and Rings')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w Height and Rings')

# %% [markdown]
# Lower the height of abalone the higher rings it has

# %%
#cheking relation between two variables

plt.scatter(df['Whole weight'],df['Rings'])
plt.ylabel('Rings')
plt.xlabel('Whole weight')
plt.title('Sctter plt b/w Whole weight and Rings')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w Whole weight and Rings')

# %% [markdown]
# As the Whole Weight increase the rings are also increasing

# %%
#cheking relation between two variables

plt.scatter(df['Shucked weight'],df['Rings'])
plt.ylabel('Rings')
plt.xlabel('Shucked weight')
plt.title('Sctter plt b/w Shucked weight and Rings')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w Shucked weight and Rings')

# %%
maximum rings are when shucked weight is less than 0.8
# Out:
#   File "<ipython-input-18-4925b09b1128>", line 1
#     maximum rings are when shucked weight is less than 0.8
#             ^
# SyntaxError: invalid syntax

# %%
#cheking relation between two variables

plt.scatter(df['Viscera weight'],df['Rings'])
plt.ylabel('Rings')
plt.xlabel('Viscera weight')
plt.title('Sctter plt b/w Viscera weight and Rings')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w Viscera weight and Rings')

# %% [markdown]
# Medium range of Viscera weight have maximun Rings

# %%
#cheking relation between two variables

plt.scatter(df['Shell weight'],df['Rings'])
plt.ylabel('Rings')
plt.xlabel('Shell weight')
plt.title('Sctter plt b/w Shell weight and Rings')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w Shell weight and Rings')

# %% [markdown]
# Medium range of Shell weight have maximun Rings

# %%
corr=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There's no negative corellation in our dataset

# %%
#Ploting skewness
for i in df.columns:
    if(df[i].dtype == np.float64):
        plt.figure()
        sns.distplot(df[i])

# %% [markdown]
# All of our data is proferly skeweed

# %%
#checking for otliers
collist=df.columns.values
ncol=7
nrow=10
plt.figure(figsize=(nrow,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='red',orient='v')
    plt.tight_layout()

# %% [markdown]
# We are having outliers in every columns

# %%
sns.pairplot(df)

# %%
df.shape
# Out:
# (4177, 9)

# %%
#Making a copy of data set
df1=df.iloc[:,1:]
df1.shape
#Removing outliers
from scipy.stats import zscore
z=np.abs(zscore(df1))
threshold=3
np.where(z>3)
df1=df1[(z<3).all(axis=1)]
df1.shape
# Out:
# (4027, 8)

# %%
#model building

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score

# %%
target=df1.iloc[:,7:8]
print(target)
data=df1.iloc[:,0:7]
print(data)
# Out:
#       Rings
# 0        15
# 1         7
# 2         9
# 3        10
# 4         7
# ...     ...
# 4172     11
# 4173     10
# 4174      9
# 4175     10
# 4176     12
#
# [4027 rows x 1 columns]
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# ...

# %%
x=data
x.shape
# Out:
# (4027, 7)

# %%
y=target
y.shape
# Out:
# (4027, 1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=50)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3020, 7)
# (3020, 1)
# (1007, 7)
# (1007, 1)

# %%
#using linear regression model because it contains continuous variables
lrm=LinearRegression()
lrm.fit(x_train,y_train)
print(lrm.coef_)
print(lrm.intercept_)
score=lrm.score(x_train,y_train)
print(score)
pred=lrm.predict(x_test)
print('predicted result:',pred)
print('actual result:',y_test)
# Out:
# [[ -3.02744057  12.95279233  23.09133141   6.90320556 -17.47302532
#    -6.3422423    7.88522293]]
# [2.72896697]
# 0.5119752428087003
# predicted result: [[ 7.94084555]
#  [ 9.1292026 ]
#  [10.43363919]
#  ...
#  [ 9.48987728]
#  [ 6.35534007]
#  [ 9.83795809]]
# actual result:       Rings
# 1464      9
# 2140     10
# 3175     11
# 1777      9
# 3736     10
# ...     ...
# 151       9
# 2162     11
# 3251      8
# 296       6
# 2327     13
#
# [1007 rows x 1 columns]

# %%
#using Random forest Regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
regr = RandomForestRegressor()
regr.fit(x_train,y_train)
score=regr.score(x_train,y_train)
print(score)

pred=regr.predict(x_test)
print('predicted result:',pred)
print('actual result:',y_test)
# Out:
# 0.9325897348705858
# predicted result: [ 8.63  8.61 12.92 ...  9.36  6.1  11.79]
# actual result:       Rings
# 1464      9
# 2140     10
# 3175     11
# 1777      9
# 3736     10
# ...     ...
# 151       9
# 2162     11
# 3251      8
# 296       6
# 2327     13
#
# [1007 rows x 1 columns]

# %%
#Using SVR
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train,y_train)
score=svr.score(x_train,y_train)
print(score)
pred=svr.predict(x_test)
print('predicted result:',pred)
print('actual result:',y_test)
# Out:
# 0.5140877330914503
# predicted result: [ 7.87912629  8.85511718 10.44977855 ...  9.23965198  5.76003337
#   9.75811937]
# actual result:       Rings
# 1464      9
# 2140     10
# 3175     11
# 1777      9
# 3736     10
# ...     ...
# 151       9
# 2162     11
# 3251      8
# 296       6
# 2327     13
#
# [1007 rows x 1 columns]

# %%
#using Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
score=dtr.score(x_train,y_train)
print(score)
pred=dtr.predict(x_test)
print('predicted result:',pred)
print('actual result:',y_test)
# Out:
# 1.0
# predicted result: [ 8.  9. 17. ...  8.  7.  9.]
# actual result:       Rings
# 1464      9
# 2140     10
# 3175     11
# 1777      9
# 3736     10
# ...     ...
# 151       9
# 2162     11
# 3251      8
# 296       6
# 2327     13
#
# [1007 rows x 1 columns]

# %%
#Saving the model
import joblib

#Save the model as a pickle in a file
joblib.dump(dtr,'abalone.pkl')
# Out:
# ['abalone.pkl']
