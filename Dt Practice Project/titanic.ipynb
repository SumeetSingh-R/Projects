# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(df.columns,'\n')
print('total variables',len(df.columns))
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
# total variables 12

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.boxplot('Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
#replacing nan values with mean value
df['Age']= df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df['Cabin'].value_counts())
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# E101           3
#               ..
# B39            1
# C111           1
# E34            1
# C90            1
# B41            1
# Name: Cabin, Length: 147, dtype: int64

# %%
#There are lot of unique values and null values so dropping this column and other non wanted columns
df=df.drop(['Cabin','PassengerId','Name','Ticket'], axis = 1)

# %%
plt.figure(figsize=(8,5))
sns.countplot('Sex',data=df,palette='ocean')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(8,5))
sns.countplot('Embarked',data=df,palette='spring')
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
plt.figure(figsize=(8,5))
sns.countplot('Survived',data=df,palette='summer')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=(8,5))
sns.countplot('Pclass',data=df,palette='twilight')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
plt.figure(figsize=(8,5))
sns.countplot('Fare',data=df,palette='flag')
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='count'>

# %%
plt.figure(figsize=(8,5))
sns.countplot('Parch',data=df,palette='ocean')
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %%
#cheking relation between two variables

plt.scatter(df['Survived'],df['Sex'])
plt.ylabel('Sex')
plt.xlabel('Survived')
plt.title('Sctter plt b/w Survived and Sex')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w Survived and Sex')

# %%
#cheking relation between two variables

plt.scatter(df['Survived'],df['Pclass'])
plt.ylabel('Pclass')
plt.xlabel('Survived')
plt.title('Sctter plt b/w Survived and Pclass')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w Survived and Pclass')

# %%
#cheking relation between two variables

plt.scatter(df['Survived'],df['Parch'])
plt.ylabel('Parch')
plt.xlabel('Survived')
plt.title('Sctter plt b/w Survived and Parch')
# Out:
# Text(0.5, 1.0, 'Sctter plt b/w Survived and Parch')

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column Sex,Embarked.
df['Embarked']= label_encoder.fit_transform(df['Embarked'])
  
df['Embarked'].unique()
# Out:
# array([2, 0, 1, 3])

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column Sex,Embarked.
df['Sex']= label_encoder.fit_transform(df['Sex'])
  
df['Sex'].unique()
# Out:
# array([1, 0])

# %%
df.head
# Out:
# <bound method NDFrame.head of      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.000000      1      0   7.2500         2
# 1           1       1    0  38.000000      1      0  71.2833         0
# 2           1       3    0  26.000000      0      0   7.9250         2
# 3           1       1    0  35.000000      1      0  53.1000         2
# 4           0       3    1  35.000000      0      0   8.0500         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000         2
# 887         1       1    0  19.000000      0      0  30.0000         2
# 888         0       3    0  29.699118      1      2  23.4500         2
# 889         1       1    1  26.000000      0      0  30.0000         0
# 890         0       3    1  32.000000      0      0   7.7500         1
#
# [891 rows x 8 columns]>

# %%
#checking for otliers
collist=df.columns.values
ncol=7
nrow=10
plt.figure(figsize=(nrow,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='blue',orient='v')
    plt.tight_layout()

# %%
#Removing outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
df=df[(z<3).all(axis=1)]
df.shape
# Out:
# (820, 8)

# %%
#Ploting skewness
for i in df.columns:
    if(df[i].dtype == np.float64):
        plt.figure()
        sns.distplot(df[i])

# %%
corr=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
target=df.iloc[:,0:1]
print(target)
data=df.iloc[:,1:]
print(data)
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [820 rows x 1 columns]
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    1  22.000000      1      0   7.2500         2
# 1         1    0  38.000000      1      0  71.2833         0
# 2         3    0  26.000000      0      0   7.9250         2
# 3         1    0  35.000000      1      0  53.1000         2
# 4         3    1  35.000000      0      0   8.0500         2
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    1  27.000000      0      0  13.0000         2
# 887       1    0  19.000000      0      0  30.0000         2
# 888       3    0  29.699118      1      2  23.4500         2
# 889       1    1  26.000000      0      0  30.0000         0
# 890       3    1  32.000000      0      0   7.7500         1
#
# ...

# %%
x=data
x.shape
# Out:
# (820, 7)

# %%
y=target
y.shape
# Out:
# (820, 1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=50)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (615, 7)
# (615, 1)
# (205, 7)
# (205, 1)

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.naive_bayes import GaussianNB      
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score

# %%
#Logistic Regression
lg=LogisticRegression()
lg.fit(x_train,y_train)
lg.score(x_train,y_train)
predlg=lg.predict(x_test)
score_lg=accuracy_score(y_test,predlg)
print("Accuracy Score:",accuracy_score(y_test,predlg))
print(confusion_matrix(y_test,predlg))
# Out:
# Accuracy Score: 0.8097560975609757
# [[100  19]
#  [ 20  66]]

# %%
#using Random forest Regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
regr = RandomForestRegressor()
regr.fit(x_train,y_train)
score=regr.score(x_train,y_train)
print(score)
pred=regr.predict(x_test)
print('predicted result:',pred)
print('actual result:',y_test)
# Out:
# 0.8864557370381253
# predicted result: [0.34       0.28       0.3        0.0925     0.77       1.
#  0.04654762 0.895      0.73       0.16       0.0025     1.
#  0.17333333 0.87       1.         0.1        0.74       0.11
#  0.74       0.42       0.68633333 1.         0.0325     0.00485714
#  0.03       0.87       0.05       1.         1.         1.
#  0.51       0.93       0.02366667 0.23333333 0.37       0.77
#  0.06854762 0.71       0.74025397 0.         0.93289286 0.07869048
#  0.00416667 0.8        1.         1.         0.3        0.94
#  1.         0.795      0.93       0.96       0.         0.11
#  0.         0.06854762 0.63       0.01       0.5        0.45
#  0.4        0.         0.01       0.74025397 0.92589286 0.01809524
#  1.         0.37       0.1375     0.8925     0.73453968 0.14162771
#  0.74       0.102      0.91       0.98       0.14162771 0.
#  0.74025397 0.02       0.00333333 0.37       0.07833333 0.89396825
# ...

# %%
#gaussian NB
gnb=GaussianNB()
gnb.fit(x_train,y_train)
gnb.score(x_train,y_train)
predgnb=gnb.predict(x_test)
score_gnb=accuracy_score(y_test,predgnb)
score_gnb=accuracy_score(y_test,predgnb)
print("Accuracy Score:",accuracy_score(y_test,predgnb))
print(confusion_matrix(y_test,predgnb))
# Out:
# Accuracy Score: 0.7853658536585366
# [[95 24]
#  [20 66]]

# %%
#support vector classifier
svc=SVC()
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
score_svc=accuracy_score(y_test,predsvc)
print("Accuracy Score:",accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# Accuracy Score: 0.6682926829268293
# [[105  14]
#  [ 54  32]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.88      0.76       119
#            1       0.70      0.37      0.48        86
#
#     accuracy                           0.67       205
#    macro avg       0.68      0.63      0.62       205
# weighted avg       0.68      0.67      0.64       205

# %%
#decision tree classifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
score_dtc=accuracy_score(y_test,preddtc)
print("Accuracy Score:",accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
# Out:
# Accuracy Score: 0.7219512195121951
# [[85 34]
#  [23 63]]

# %%
#knn
knc=KNeighborsClassifier()
knc.fit(x_train,y_train)
knc.score(x_train,y_train)
predknc=knc.predict(x_test)
score_knn=accuracy_score(y_test,predknc)
print("Accuracy Score:",accuracy_score(y_test,predknc))
print(confusion_matrix(y_test,predknc))
# Out:
# Accuracy Score: 0.6926829268292682
# [[92 27]
#  [36 50]]

# %%
#Using Random Forest Classifier
from sklearn import metrics
rf=RandomForestClassifier(criterion='gini', random_state=50,n_estimators=100)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
score_rf=accuracy_score(y_test,predrf)
print('accuracy score:',accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
# Out:
# accuracy score: 0.7804878048780488
# [[95 24]
#  [21 65]]

# %%
#Saving the model
import joblib

#Save the model as a pickle in a file
joblib.dump(rf,'titanic.pkl')
# Out:
# ['titanic.pkl']
